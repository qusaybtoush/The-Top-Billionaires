# %% [markdown]
# # Introduction 😃😃😃
#
# - We have small DataSet for making Data Analysis
#
# ## The Top Billionaires
#
# - According to Bloomberg/Forbes, the 10 richest people on the planet.
#
# ## About Dataset
#
# - Data for the last five years. Interesting dynamics of capitalization of companies. How do people make money in technology companies.
#
#
#
# # Data Exploration & Analysis 🤝🤝🤝

# %%
#Importing the basic librarires fot analysis

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")  #using style ggplot

# %matplotlib inline
import plotly.graph_objects as go
import plotly.express as px

# %%
#Importing the dataset
df=pd.read_csv("../input/the-top-billionaires/The Top Billionaires.csv")

# look the data set
df.head()
# Out:
#               NAME   2018   2019   2020   2021   2022
# 0        Elon Musk   19.9   22.3   24.6  151.0  219.0
# 1       Jeff Bezos  112.0  131.0  113.0  177.0  171.0
# 2  Bernard Arnault   72.0   76.0   76.0  150.0  158.0
# 3       Bill Gates   90.0   96.5   98.0  124.0  129.0
# 4   Warren Buffett   84.0   82.5   67.5   96.0  118.0

# %%
# looking the shape DataSet
df.shape
# Out:
# (10, 6)

# %% [markdown]
# - it`s small data set

# %%
#Checking the dtypes of all the columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    10 non-null     object
#  1   2018    10 non-null     float64
#  2   2019    10 non-null     float64
#  3   2020    10 non-null     float64
#  4   2021    10 non-null     float64
#  5   2022    10 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 608.0+ bytes

# %%
# let see the data describe
df.describe().round(2)
# Out:
#          2018    2019    2020    2021    2022
# count   10.00   10.00   10.00   10.00   10.00
# mean    61.12   66.26   62.76  112.47  130.11
# std     28.02   31.29   26.95   35.79   40.87
# min     19.90   22.30   24.60   68.70   90.70
# 25%     41.95   49.85   49.55   89.62  106.25
# 50%     53.65   56.65   55.85   94.50  114.50
# 75%     81.00   80.88   73.88  143.50  150.75
# max    112.00  131.00  113.00  177.00  219.00

# %% [markdown]
# # Visualizations

# %%
# library seaborn from make line graph

plt.figure(figsize=(20,7))
sns.lineplot(data=df,x="NAME",y="2018",label="2018")
sns.lineplot(data=df,x="NAME",y="2019",label="2019")
sns.lineplot(data=df,x="NAME",y="2020",label="2020")
sns.lineplot(data=df,x="NAME",y="2021",label="2021")
sns.lineplot(data=df,x="NAME",y="2022",label="2022")
# Out:
# <AxesSubplot:xlabel='NAME', ylabel='2018'>

# %%
df.set_index("NAME").plot(kind="bar",figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='NAME'>

# %% [markdown]
# - This graph show - Elon Musk - the first 3 year be less have money then he become rich person , he is genius ,

# %%
plt.figure(figsize=(20,12))
plt.pie(data=df,x="2018",labels="NAME",autopct='%1.1f%%',shadow=True)
plt.title("The Rich in 2018")
plt.show()

# %% [markdown]
# #### In the year 2018
# - 1- Jeff Bezos
# - 2- Bill Gates

# %%
plt.figure(figsize=(20,12))
plt.pie(data=df,x="2019",labels="NAME",autopct='%1.1f%%',shadow=True)
plt.title("The Rich in 2019")
plt.show()

# %% [markdown]
# ### In the year 2019
# - 1- Jeff Bezos
# - 2- Bill Gates

# %%
plt.figure(figsize=(20,12))
plt.pie(data=df,x="2020",labels="NAME",autopct='%1.1f%%',shadow=True)
plt.title("The Rich in 2020")
plt.show()

# %% [markdown]
# #### In the year 2020
# - 1- Jeff Bezos
# - 2- Bill Gates

# %%
plt.figure(figsize=(20,12))
plt.pie(data=df,x="2021",labels="NAME",autopct='%1.1f%%',shadow=True)
plt.title("The Rich in 2021")
plt.show()

# %% [markdown]
# #### In the year 2021
# - 1- Jeff Bezos
# - 2- Bernard Arnault

# %%
plt.figure(figsize=(20,12))
plt.pie(data=df,x="2022",labels="NAME",autopct='%1.1f%%',shadow=True)
plt.title("The Rich in 2022")
plt.show()

# %% [markdown]
# #### In the year 2022
# - 1- Elon Musk
# - 2- Jeff Bezos

# %% [markdown]
# # Summary
#
# - We have small DataSet for making Data Analysis about The Top Billionaires , the 10 richest people on the planet.
#
#
# ### Elon Musk - the first 3 year be less have money then he become rich person
#
#
#
# ## In the year 2018 the highest persons
# - 1- Jeff Bezos
# - 2- Bill Gates
#
#
#
# ## In the year 2019 the highest persons
# - 1- Jeff Bezos
# - 2- Bill Gates
#
#
#
# ## In the year 2020 the highest persons
# - 1- Jeff Bezos
# - 2- Bill Gates
#
#
#
# ## In the year 2021 the highest persons
# - 1- Jeff Bezos
# - 2- Bernard Arnault
#
#
#
# ## In the year 2022 the highest persons
# - 1- Elon Musk
# - 2- Jeff Bezos
#
#
# ## Now the the highest persons = Elon Musk
#
#
# # The End 🎉🎉🎉🎉
#
# - Thank for reading my analysis ,
# - If you any questions or advice me please write in the comment ,
#
#
# # Vote 🤝🤝🤝🤝🤝
#
# - also if you liked my analysis upvote me ,
